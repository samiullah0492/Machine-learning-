# %% [markdown]
# # Lab 7: Image Dataset Preparation for Computer Vision
#
# **Student Name:** Samiullah Khan
# **Registration Number:** 22JZELE0492
# **Course:** Machine Learning Lab
# **Supervisor:** Engr. Irshad Ullah
# **University:** UET Peshawar - Nowshera Campus
#
# ## Lab Overview
# This notebook prepares a corn leaf image dataset for computer vision model training. It creates train, validation, and test directories, selects image classes, and copies images into the folder structure required by Keras image generators.
#
# ## Learning Objectives
# - Understand how image datasets are organized for classification tasks.
# - Create training, validation, and testing directories using Python.
# - Separate selected corn leaf disease classes into class-wise folders.
# - Prepare the dataset structure required for CNN model training in the next lab.

# %% [markdown]
# ## Section 1: Lab Task and Dataset Selection
# This section describes the selected corn leaf image categories and the required number of images for training, validation, and testing.

# %% [markdown]
# ## Lab Task 1
#
# Select only two categories:
#
# ### Category 1: Healthy
# Use 120 images for training, 30 images for validation, and 12 images for testing.
#
# ### Category 2: Unhealthy
# Combine the other three classes. From each remaining class, select:
#
# - 40 images for training
# - 10 images for validation
# - 4 images for testing

# %% [markdown]
# ## Lab Practice Task
#
# Select two difficult classes:
#
# ### Class 1: Cercospora
# Use 120 images for training, 30 images for validation, and 10 images for testing.
#
# ### Class 2: Northern Leaf Blight
# Use 120 images for training, 30 images for validation, and 10 images for testing.

# %%
# Import file-management libraries and define dataset locations.
import os, shutil
original_dataset_dir = r'C:\Users\Sami\Documents\MachineLearning\Material\ML\Lab 7,8\Corn'
base_dir = r'C:\Users\Sami\Documents\MachineLearning\Material\ML\Lab 7,8\Computer vision\sectionB'

# %% [markdown]
# ## Section 2: Directory Setup
# The following cells create the base computer vision dataset directory along with train, validation, and test folders.

# %%
base_dir
# Out:
# 'Z:\\University\\8th Semester\\ML Lab\\Lab 7,8\\Computer vision\\sectionB'

# %%
os.path.join(base_dir, 'train')
# Out:
# 'Z:\\University\\8th Semester\\ML Lab\\Lab 7,8\\Computer vision\\sectionB\\train'

# %%
# Create the main output directory and the train/validation/test split folders.
os.makedirs(base_dir, exist_ok=True)

train_dir = os.path.join(base_dir, "train")
validation_dir = os.path.join(base_dir, "validation")
test_dir = os.path.join(base_dir, "test")

os.makedirs(train_dir, exist_ok=True)
os.makedirs(validation_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# %% [markdown]
# ## Section 3: Class Folder Creation and Image Copying
# This section creates class-specific folders and copies selected images from the original dataset into the prepared structure.

# %%
# Create one class folder inside each dataset split.
train_healthy_dir = os.path.join(train_dir, 'healthy')
os.makedirs(train_healthy_dir, exist_ok=True)

train_Cercospora_dir = os.path.join(train_dir, 'Cercospora')
os.makedirs(train_Cercospora_dir, exist_ok=True)

train_common_rust_dir = os.path.join(train_dir, 'common_rust')
os.makedirs(train_common_rust_dir, exist_ok=True)

train_northern_leaf_blight_dir = os.path.join(train_dir, 'northern_leaf_blight')
os.makedirs(train_northern_leaf_blight_dir, exist_ok=True)

validation_healthy_dir = os.path.join(validation_dir, 'healthy')
os.makedirs(validation_healthy_dir, exist_ok=True)

validation_Cercospora_dir = os.path.join(validation_dir, 'Cercospora')
os.makedirs(validation_Cercospora_dir, exist_ok=True)

validation_common_rust_dir = os.path.join(validation_dir, 'common_rust')
os.makedirs(validation_common_rust_dir, exist_ok=True)

validation_northern_leaf_blight_dir = os.path.join(validation_dir, 'northern_leaf_blight')
os.makedirs(validation_northern_leaf_blight_dir, exist_ok=True)

test_healthy_dir = os.path.join(test_dir, 'healthy')
os.makedirs(test_healthy_dir, exist_ok=True)

test_Cercospora_dir = os.path.join(test_dir, 'Cercospora')
os.makedirs(test_Cercospora_dir, exist_ok=True)

test_common_rust_dir = os.path.join(test_dir, 'common_rust')
os.makedirs(test_common_rust_dir, exist_ok=True)

test_northern_leaf_blight_dir = os.path.join(test_dir, 'northern_leaf_blight')
os.makedirs(test_northern_leaf_blight_dir, exist_ok=True)

# %%
# Copy training images for each corn leaf class into its training folder.
src_healthy_path = os.path.join(original_dataset_dir, 'Corn_(maize)___healthy')
src_list = os.listdir(src_healthy_path)
fnames = ['healthy.{}.jpg'.format(i) for i in range(400)]
for i in range(400):
    src = os.path.join(src_healthy_path, src_list[i])
    dst = os.path.join(train_healthy_dir, fnames[i])
    shutil.copyfile(src, dst)

src_Cercospora_path = os.path.join(original_dataset_dir, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot')
src_list = os.listdir(src_Cercospora_path)
fnames = ['Cercospora.{}.jpg'.format(i) for i in range(400)]
for i in range(400):
    src = os.path.join(src_Cercospora_path, src_list[i])
    dst = os.path.join(train_Cercospora_dir, fnames[i])
    shutil.copyfile(src, dst)

src_Common_rust_path = os.path.join(original_dataset_dir, 'Corn_(maize)___Common_rust_')
src_list = os.listdir(src_Common_rust_path)
fnames = ['common_rust.{}.jpg'.format(i) for i in range(400)]
for i in range(400):
    src = os.path.join(src_Common_rust_path, src_list[i])
    dst = os.path.join(train_common_rust_dir, fnames[i])
    shutil.copyfile(src, dst)

src_Northern_Leaf_Blight_path = os.path.join(original_dataset_dir, 'Corn_(maize)___Northern_Leaf_Blight')
src_list = os.listdir(src_Northern_Leaf_Blight_path)
fnames = ['Northern_Leaf_Blight.{}.jpg'.format(i) for i in range(400)]
for i in range(400):
    src = os.path.join(src_Northern_Leaf_Blight_path, src_list[i])
    dst = os.path.join(train_northern_leaf_blight_dir, fnames[i])
    shutil.copyfile(src, dst)

# %%
# Copy validation images for each corn leaf class into its validation folder.
src_healthy_path = os.path.join(original_dataset_dir, 'Corn_(maize)___healthy')
src_list = os.listdir(src_healthy_path)
fnames = ['healthy.{}.jpg'.format(i) for i in range(63)]
for i in range(400,463):
    src = os.path.join(src_healthy_path, src_list[i])
    dst = os.path.join(validation_healthy_dir, fnames[i-400])
    shutil.copyfile(src, dst)

src_Cercospora_path = os.path.join(original_dataset_dir, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot')
src_list = os.listdir(src_Cercospora_path)
fnames = ['Cercospora.{}.jpg'.format(i) for i in range(63)]
for i in range(400,463):
    src = os.path.join(src_Cercospora_path, src_list[i])
    dst = os.path.join(validation_Cercospora_dir, fnames[i-400])
    shutil.copyfile(src, dst)

src_Common_rust_path = os.path.join(original_dataset_dir, 'Corn_(maize)___Common_rust_')
src_list = os.listdir(src_Common_rust_path)
fnames = ['common_rust.{}.jpg'.format(i) for i in range(63)]
for i in range(400,463):
    src = os.path.join(src_Common_rust_path, src_list[i])
    dst = os.path.join(validation_common_rust_dir, fnames[i-400])
    shutil.copyfile(src, dst)

src_Northern_Leaf_Blight_path = os.path.join(original_dataset_dir, 'Corn_(maize)___Northern_Leaf_Blight')
src_list = os.listdir(src_Northern_Leaf_Blight_path)
fnames = ['Northern_Leaf_Blight.{}.jpg'.format(i) for i in range(63)]
for i in range(400,463):
    src = os.path.join(src_Northern_Leaf_Blight_path, src_list[i])
    dst = os.path.join(validation_northern_leaf_blight_dir, fnames[i-400])
    shutil.copyfile(src, dst)

# %% [markdown]
# ## Section 4: Test Dataset Preparation
# The final cells prepare the test data folders so that the trained CNN can be evaluated on unseen images.

# %% [markdown]
# ## Test Dataset

# %%
# Copy test images for each corn leaf class into its test folder.
src_healthy_path = os.path.join(original_dataset_dir, 'Corn_(maize)___healthy')
src_list = os.listdir(src_healthy_path)
fnames = ['healthy.{}.jpg'.format(i) for i in range(50)]
for i in range(463,513):
    src = os.path.join(src_healthy_path, src_list[i])
    dst = os.path.join(test_healthy_dir, fnames[i-463])
    shutil.copyfile(src, dst)

src_Cercospora_path = os.path.join(original_dataset_dir, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot')
src_list = os.listdir(src_Cercospora_path)
fnames = ['Cercospora.{}.jpg'.format(i) for i in range(50)]
for i in range(463,513):
    src = os.path.join(src_Cercospora_path, src_list[i])
    dst = os.path.join(test_Cercospora_dir, fnames[i-463])
    shutil.copyfile(src, dst)

src_Common_rust_path = os.path.join(original_dataset_dir, 'Corn_(maize)___Common_rust_')
src_list = os.listdir(src_Common_rust_path)
fnames = ['common_rust.{}.jpg'.format(i) for i in range(50)]
for i in range(463,513):
    src = os.path.join(src_Common_rust_path, src_list[i])
    dst = os.path.join(test_common_rust_dir, fnames[i-463])
    shutil.copyfile(src, dst)

src_Northern_Leaf_Blight_path = os.path.join(original_dataset_dir, 'Corn_(maize)___Northern_Leaf_Blight')
src_list = os.listdir(src_Northern_Leaf_Blight_path)
fnames = ['Northern_Leaf_Blight.{}.jpg'.format(i) for i in range(50)]
for i in range(463,513):
    src = os.path.join(src_Northern_Leaf_Blight_path, src_list[i])
    dst = os.path.join(test_northern_leaf_blight_dir, fnames[i-463])
    shutil.copyfile(src, dst)

# %% [markdown]
# ## Final Conclusion
# In this lab, the corn leaf dataset was organized into train, validation, and test folders. This prepared image dataset can now be used directly for CNN training and evaluation.
#
# ## Submitted By
# **Student Name:** Samiullah Khan
# **Registration Number:** 22JZELE0492
# **Course:** Machine Learning Lab
# **Supervisor:** Engr. Irshad Ullah
# **University:** UET Peshawar - Nowshera Campus
